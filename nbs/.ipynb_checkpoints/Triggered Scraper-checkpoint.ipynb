# %%
from selenium import webdriver
from selenium.webdriver import ChromeOptions

# %%
options = ChromeOptions()
# options.add_argument('--headless')

# %%
url = 'https://www.amazon.in/Sony-CFI-2008A01X-PlayStation%C2%AE5-Console-slim/dp/B0CY5HVDS2/ref=sr_1_1?adgrpid=61752779214&dib=eyJ2IjoiMSJ9.LFVt-P4VfYSI0tw5J_cegag4lJ5FRb1NWVTzAfnaQoW-gjtU-u7QdA1mxUMYDT5eCHVH_WszHXxlBhKdxurqW5k3rswLLmcrXyoMW90wa5OIbr6eRbsmvW4VKUbqqW89QM8bRkwyAu6-xa5qEMnBekzPrNV5gkZTwceJsWW_TxSNGRZ7GdmZu60lBOXMIwIvAMRT8wdQeaH6qZgZjCJ39kEsHc3QcY7DzMkwYLAoqF8.OfhufCqj937W-PHIrPzhXnrq1pcsGn-mRa65iJ6JuZ8&dib_tag=se&ext_vrnc=hi&hvadid=329010392289&hvdev=c&hvlocphy=9061770&hvnetw=g&hvqmt=b&hvrand=7314834578568745260&hvtargid=kwd-568826147206&hydadcr=9535_1834886&keywords=sony+playstation+ps5&nsdOptOutParam=true&qid=1734639430&sr=8-1'

# %%
import time
with webdriver.Chrome(options=options) as driver:
    driver.get(url)
    time.sleep(10)
    html = driver.page_source

# %%
print(html)
# Out:
# <html lang="en-in" class=" a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d -scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.24.10-2024-12-16"><!-- sp:feature:head-start --><head><script async="" src="https://c.amazon-adsystem.com/bao-csm/forensics/a9-tq-forensics-incremental.min.js" crossorigin="anonymous"></script><script async="" src="https://images-eu.ssl-images-amazon.com/images/I/31bJewCvY-L.js" crossorigin="anonymous"></script><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style><style class="vjs-styles-dimensions">
# ...
